# %% [markdown]
# <a href="https://colab.research.google.com/github/tekotechkotech/wpu-resolusi/blob/main/Realtime_Voice_Changer_on_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### [w-okada's Voice Changer](https://github.com/w-okada/voice-changer) | **Colab**
#
# ---
#
# ## **⬇ VERY IMPORTANT ⬇**
#
# You can use the following settings for better results:
#
# If you're using a index: `f0: RMVPE_ONNX | Chunk: 112 or higher | Extra: 8192`<br>
# If you're not using a index: `f0: RMVPE_ONNX | Chunk: 96 or higher | Extra: 16384`<br>
# **Don't forget to select a T4 GPU in the GPU field, <b>NEVER</b> use CPU!
# > Seems that PTH models performance better than ONNX for now, you can still try ONNX models and see if it satisfies you
#
#
# *You can always [click here](https://github.com/YunaOneeChan/Voice-Changer-Settings) to check if these settings are up-to-date*
#
# ---
#
# ### <font color=red>⬇ Always use Colab GPU! (**IMPORTANT!**) ⬇</font>
# You need to use a Colab GPU so the Voice Changer can work faster and better\
# Use the menu above and click on **Runtime** » **Change runtime** » **Hardware acceleration** to select a GPU (**T4 is the free one**)
#
# ---
# **Credits**<br>
# Realtime Voice Changer by [w-okada](https://github.com/w-okada)<br>
# Notebook files updated by [rafacasari](https://github.com/Rafacasari)<br>
# Recommended settings by [YunaOneeChan](https://github.com/YunaOneeChan)
#
# **Need help?** [AI Hub Discord](https://discord.gg/aihub) » ***#help-realtime-vc***
#
# ---

# %%
# @title Clone repository and install dependencies (FINAL FIX + All Audio Deps)
# @markdown This first step will download the latest version of Voice Changer and install the dependencies. **It can take some time to complete.**
# %cd /content/

# !pip install colorama --quiet
from colorama import Fore, Style
import os, shutil, sys

print(f"{Fore.CYAN}> Cloning the repository...{Style.RESET_ALL}")
# Hapus direktori lama jika ada untuk menghindari error 'already exists'
repo_path = "/content/voice-changer"
if os.path.exists(repo_path):
    print(f"{Fore.YELLOW}> Removing existing directory...{Style.RESET_ALL}")
    shutil.rmtree(repo_path)
# !git clone https://github.com/w-okada/voice-changer.git --quiet
print(f"{Fore.GREEN}> Successfully cloned the repository!{Style.RESET_ALL}")
# %cd voice-changer/server/

print(f"{Fore.CYAN}> Installing libportaudio2...{Style.RESET_ALL}")
# !apt-get -y install libportaudio2 -qq

print(f"{Fore.CYAN}> Downgrading pip temporarily for compatibility...{Style.RESET_ALL}")
# Downgrade pip ke versi < 24.1 agar bisa membaca metadata omegaconf lama
# !pip install 'pip<24.1' --quiet --force-reinstall

print(f"{Fore.CYAN}> Installing pre-dependencies (FINAL)...{Style.RESET_ALL}")

# Install all known required audio/ML packages explicitly
print(f"{Fore.CYAN}> Installing sounddevice...{Style.RESET_ALL}")
# !pip install sounddevice --quiet

print(f"{Fore.CYAN}> Installing resampy...{Style.RESET_ALL}")
# !pip install resampy --quiet

print(f"{Fore.CYAN}> Installing praat-parselmouth...{Style.RESET_ALL}")
# !pip install praat-parselmouth --quiet

print(f"{Fore.CYAN}> Installing librosa...{Style.RESET_ALL}")
# !pip install librosa --quiet

# Instal omegaconf versi stabil terlebih dahulu
print(f"{Fore.CYAN}> Installing omegaconf...{Style.RESET_ALL}")
# !pip install 'omegaconf>=2.1,<2.4' --quiet

# Instal faiss-cpu, pyngrok
print(f"{Fore.CYAN}> Installing faiss-cpu and pyngrok...{Style.RESET_ALL}")
# !pip install faiss-cpu pyngrok --quiet

# Instal fairseq tanpa dependensi (omegaconf sudah diinstal)
print(f"{Fore.CYAN}> Installing fairseq...{Style.RESET_ALL}")
# !pip install fairseq --no-deps --quiet

# Attempt to install pyworld
try:
    print(f"{Fore.CYAN}> Attempting to install pyworld...{Style.RESET_ALL}")
    # !pip install pyworld --no-build-isolation --no-cache-dir --quiet
    print(f"{Fore.GREEN}> pyworld installed successfully!{Style.RESET_ALL}")
except Exception as e:
    print(f"{Fore.RED}> Failed to install pyworld. Error: {e}{Style.RESET_ALL}")
    print(f"{Fore.YELLOW}> Proceeding without pyworld. Some features might be unavailable.{Style.RESET_ALL}")

# Install onnxruntime explicitly
print(f"{Fore.CYAN}> Installing onnxruntime...{Style.RESET_ALL}")
# !pip install onnxruntime --quiet

# Install torch and related packages (often needed)
print(f"{Fore.CYAN}> Installing torch packages...{Style.RESET_ALL}")
# !pip install torch torchvision torchaudio --quiet

print(f"{Fore.CYAN}> Installing remaining dependencies from requirements.txt...{Style.RESET_ALL}")
try:
    # !pip install -r requirements.txt --quiet --no-build-isolation
except Exception as e:
    print(f"{Fore.YELLOW}> Warning: Some packages from requirements.txt might have failed. Error: {e}{Style.RESET_ALL}")

# Upgrade pip back to latest version to avoid issues with other packages
print(f"{Fore.CYAN}> Restoring latest pip version...{Style.RESET_ALL}")
# !pip install --upgrade pip --quiet

print(f"{Fore.GREEN}> Installation process completed. Check for warnings above.{Style.RESET_ALL}")

# %%
# @title Start Server **using ngrok** (Fixed)
# @markdown This cell will start the server, the first time that you run it will download the models, so it can take a while (~1-2 minutes)

# @markdown ---
# @markdown You'll need a ngrok account, but <font color=green>**it's free**</font> and easy to create!
# @markdown ---
# @markdown **1** - Create a <font color=green>**free**</font> account at [ngrok](https://dashboard.ngrok.com/signup) or **login with Google/Github account**\
# @markdown **2** - If you didn't logged in with Google/Github, you will need to **verify your e-mail**!\
# @markdown **3** - Click [this link](https://dashboard.ngrok.com/get-started/your-authtoken) to get your auth token, and place it here:
Token = '2JxIOMkM6ty2OKXV5YpJQ0NCP94_6bWNju5UWPBqGaZkSxMk2' # @param {type:"string"}
# @markdown **4** - *(optional)* Change to a region near to you or keep at United States if increase latency\
# @markdown `Default Region: us - United States (Ohio)`
Region = "ap - Asia/Pacific (Singapore)" # @param ["ap - Asia/Pacific (Singapore)", "au - Australia (Sydney)","eu - Europe (Frankfurt)", "in - India (Mumbai)","jp - Japan (Tokyo)","sa - South America (Sao Paulo)", "us - United States (Ohio)"]

#@markdown **5** - *(optional)* Other options:
ClearConsole = True  # @param {type:"boolean"}

# ---------------------------------
# DO NOT TOUCH ANYTHING DOWN BELOW!
# ---------------------------------

import os
import sys

# Verify the working directory exists
work_dir = "/content/voice-changer/server"
if not os.path.exists(work_dir):
    print(f"ERROR: Working directory '{work_dir}' does not exist.")
    print("Make sure the previous cell completed successfully.")
    sys.exit(1)

# %cd {work_dir}

# Ensure pyngrok is installed before importing
if 'pyngrok' not in sys.modules:
    import subprocess
    subprocess.check_call([sys.executable, "-m", "pip", "install", "pyngrok"])
from pyngrok import conf, ngrok

MyConfig = conf.PyngrokConfig()
MyConfig.auth_token = Token
MyConfig.region = Region[0:2]
conf.set_default(MyConfig);

import subprocess, threading, time, socket, urllib.request
PORT = 8000

ngrokConnection = ngrok.connect(PORT)
public_url = ngrokConnection.public_url

from IPython.display import clear_output

def wait_for_server():
    while True:
        time.sleep(0.5)
        sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
        result = sock.connect_ex(('127.0.0.1', PORT))
        if result == 0:
            break
        sock.close()
    if ClearConsole:
        clear_output()
    print("--------- SERVER READY! ---------")
    print("Your server is available at:")
    print(public_url)
    print("---------------------------------")

threading.Thread(target=wait_for_server, daemon=True).start()

# !python3 MMVCServerSIO.py \
  -p {PORT} \
  --https False \
  --content_vec_500 pretrain/checkpoint_best_legacy_500.pt \
  --content_vec_500_onnx pretrain/content_vec_500.onnx \
  --content_vec_500_onnx_on true \
  --hubert_base pretrain/hubert_base.pt \
  --hubert_base_jp pretrain/rinna_hubert_base_jp.pt \
  --hubert_soft pretrain/hubert/hubert-soft-0d54a1f4.pt \
  --nsf_hifigan pretrain/nsf_hifigan/model \
  --crepe_onnx_full pretrain/crepe_onnx_full.onnx \
  --crepe_onnx_tiny pretrain/crepe_onnx_tiny.onnx \
  --rmvpe pretrain/rmvpe.pt \
  --model_dir model_dir \
  --samples samples.json

ngrok.disconnect(ngrokConnection.public_url)
